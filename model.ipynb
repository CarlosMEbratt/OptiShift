# %%
import firebase_admin
from firebase_admin import credentials, firestore
import geopy.distance
from sklearn.ensemble import RandomForestClassifier
import pickle
import pandas as pd
from datetime import datetime
from geopy.geocoders import Nominatim
from sklearn.preprocessing import LabelEncoder

# Initialize Firebase Admin SDK
def initialize_firebase():
    try:
        if not firebase_admin._apps:
            cred = credentials.Certificate('serviceAccountKey.json')
            firebase_admin.initialize_app(cred)
        else:
            print("Firebase already initialized.")
    except Exception as e:
        print(f"Error initializing Firebase: {e}")

initialize_firebase()

# Initialize Firestore client
db = firestore.client()
# Out:
# Firebase already initialized.

# %%
# Fetch Employees & Job Sites
employees = [doc.to_dict() for doc in db.collection('employees').stream()]
job_sites = [doc.to_dict() for doc in db.collection('job_sites').stream()]

print(f"📋 Employees Loaded: {len(employees)}")
print(f"🏗️ Job Sites Loaded: {len(job_sites)}")
# Out:
# 📋 Employees Loaded: 50
# 🏗️ Job Sites Loaded: 4

# %%
# Geocoding function (Avoid re-geocoding addresses already stored in Firestore)
geolocator = Nominatim(user_agent="OptiShiftApp")

def geocode_address(address):
    try:
        location = geolocator.geocode(address, timeout=10)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except Exception as e:
        return None, None

# Geocode Missing Addresses
for employee in employees:
    if 'latitude' not in employee or 'longitude' not in employee:
        print(f"🔍 Missing coordinates for {employee['worker_id']}. Attempting geocode...")
        lat, lon = geocode_address(employee['home_address'])
        if lat and lon:
            employee['latitude'] = lat
            employee['longitude'] = lon
            print(f"✅ Geocoded {employee['worker_id']}: {lat}, {lon}")
        else:
            print(f"❌ Failed to geocode {employee['worker_id']}. Skipping.")

for site in job_sites:
    if 'latitude' not in site or 'longitude' not in site:
        lat, lon = geocode_address(site['address'])
        if lat and lon:
            site['latitude'] = lat
            site['longitude'] = lon
# Out:
# 🔍 Missing coordinates for DVCQQLCL. Attempting geocode...
# ✅ Geocoded DVCQQLCL: 43.5921963, -79.65138688125015
# 🔍 Missing coordinates for 2084COEC. Attempting geocode...
# ✅ Geocoded 2084COEC: 43.5922757, -79.63514028047207
# 🔍 Missing coordinates for 16SAR8R9. Attempting geocode...
# ✅ Geocoded 16SAR8R9: 43.605456849999996, -79.65300176125949
# 🔍 Missing coordinates for HNMRH170. Attempting geocode...
# ✅ Geocoded HNMRH170: 43.5921963, -79.65138688125015
# 🔍 Missing coordinates for BQYL7RR5. Attempting geocode...
# ✅ Geocoded BQYL7RR5: 43.623916449999996, -79.67202003231276
# 🔍 Missing coordinates for J30DTGPH. Attempting geocode...
# ✅ Geocoded J30DTGPH: 43.6270285, -79.6300009
# 🔍 Missing coordinates for LJVVAM2B. Attempting geocode...
# ✅ Geocoded LJVVAM2B: 43.605456849999996, -79.65300176125949
# 🔍 Missing coordinates for EOCO79YN. Attempting geocode...
# ✅ Geocoded EOCO79YN: 43.6270285, -79.6300009
# 🔍 Missing coordinates for PAWQC5I1. Attempting geocode...
# ✅ Geocoded PAWQC5I1: 43.58448695, -79.6211363943631
# 🔍 Missing coordinates for G98TAZQ0. Attempting geocode...
# ✅ Geocoded G98TAZQ0: 43.628444200000004, -79.67612546062253
# 🔍 Missing coordinates for RHXAD0DV. Attempting geocode...
# ✅ Geocoded RHXAD0DV: 43.623916449999996, -79.67202003231276
# 🔍 Missing coordinates for BE6CDBAU. Attempting geocode...
# ✅ Geocoded BE6CDBAU: 43.58540415, -79.64389344844595
# 🔍 Missing coordinates for Z6TJ0HYE. Attempting geocode...
# ✅ Geocoded Z6TJ0HYE: 43.58448695, -79.6211363943631
# 🔍 Missing coordinates for 9J3KFRDS. Attempting geocode...
# ✅ Geocoded 9J3KFRDS: 43.58448695, -79.6211363943631
# 🔍 Missing coordinates for GZW7HYV4. Attempting geocode...
# ✅ Geocoded GZW7HYV4: 43.59668175, -79.64236258952329
# 🔍 Missing coordinates for HV4N1YU3. Attempting geocode...
# ✅ Geocoded HV4N1YU3: 43.59668175, -79.64236258952329
# 🔍 Missing coordinates for FVVIJE3B. Attempting geocode...
# ✅ Geocoded FVVIJE3B: 43.58540415, -79.64389344844595
# 🔍 Missing coordinates for 2CVIC7VQ. Attempting geocode...
# ✅ Geocoded 2CVIC7VQ: 43.58540415, -79.64389344844595
# 🔍 Missing coordinates for U54CSNUX. Attempting geocode...
# ✅ Geocoded U54CSNUX: 43.574848, -79.6081777
# 🔍 Missing coordinates for 0RCT21ON. Attempting geocode...
# ✅ Geocoded 0RCT21ON: 43.597162999999995, -79.63854806252439
# 🔍 Missing coordinates for BIJFYAEX. Attempting geocode...
# ✅ Geocoded BIJFYAEX: 43.5921963, -79.65138688125015
# 🔍 Missing coordinates for OUOZRZU8. Attempting geocode...
# ✅ Geocoded OUOZRZU8: 43.610351949999995, -79.6018136205488
# 🔍 Missing coordinates for L2065SCJ. Attempting geocode...
# ✅ Geocoded L2065SCJ: 43.628444200000004, -79.67612546062253
# 🔍 Missing coordinates for ZQUO11WI. Attempting geocode...
# ✅ Geocoded ZQUO11WI: 43.6067546, -79.64894838560983
# 🔍 Missing coordinates for L8KRBRVM. Attempting geocode...
# ✅ Geocoded L8KRBRVM: 43.6067546, -79.64894838560983
# 🔍 Missing coordinates for BS7MDBKD. Attempting geocode...
# ✅ Geocoded BS7MDBKD: 43.58540415, -79.64389344844595
# 🔍 Missing coordinates for XJQ933JG. Attempting geocode...
# ✅ Geocoded XJQ933JG: 43.574848, -79.6081777
# 🔍 Missing coordinates for ITYDRX2R. Attempting geocode...
# ✅ Geocoded ITYDRX2R: 43.58540415, -79.64389344844595
# 🔍 Missing coordinates for 28UU8BQV. Attempting geocode...
# ✅ Geocoded 28UU8BQV: 43.597162999999995, -79.63854806252439
# 🔍 Missing coordinates for HTOB5Y41. Attempting geocode...
# ✅ Geocoded HTOB5Y41: 43.597162999999995, -79.63854806252439
# 🔍 Missing coordinates for SSFSGDGP. Attempting geocode...
# ✅ Geocoded SSFSGDGP: 43.574848, -79.6081777
# 🔍 Missing coordinates for Q3IBWY3K. Attempting geocode...
# ✅ Geocoded Q3IBWY3K: 43.5939118, -79.64389219049735
# 🔍 Missing coordinates for YTLHDOG6. Attempting geocode...
# ✅ Geocoded YTLHDOG6: 43.574848, -79.6081777
# 🔍 Missing coordinates for 9G60YI43. Attempting geocode...
# ✅ Geocoded 9G60YI43: 43.574848, -79.6081777
# 🔍 Missing coordinates for JIOOGY7I. Attempting geocode...
# ✅ Geocoded JIOOGY7I: 43.628444200000004, -79.67612546062253
# 🔍 Missing coordinates for MZJPLU5R. Attempting geocode...
# ✅ Geocoded MZJPLU5R: 43.5921963, -79.65138688125015
# 🔍 Missing coordinates for 7IXCOMM1. Attempting geocode...
# ✅ Geocoded 7IXCOMM1: 43.58540415, -79.64389344844595
# 🔍 Missing coordinates for RXBD2LAO. Attempting geocode...
# ✅ Geocoded RXBD2LAO: 43.58448695, -79.6211363943631
# 🔍 Missing coordinates for VIZCOHA6. Attempting geocode...
# ✅ Geocoded VIZCOHA6: 43.5939118, -79.64389219049735
# 🔍 Missing coordinates for X092XPU8. Attempting geocode...
# ✅ Geocoded X092XPU8: 43.62683465, -79.67767878176727
# 🔍 Missing coordinates for LJGFMSYJ. Attempting geocode...
# ✅ Geocoded LJGFMSYJ: 43.62683465, -79.67767878176727
# 🔍 Missing coordinates for YTLY0XPU. Attempting geocode...
# ✅ Geocoded YTLY0XPU: 43.610351949999995, -79.6018136205488
# 🔍 Missing coordinates for 0A9Z7O58. Attempting geocode...
# ✅ Geocoded 0A9Z7O58: 43.605456849999996, -79.65300176125949
# 🔍 Missing coordinates for NA5LXZQ3. Attempting geocode...
# ✅ Geocoded NA5LXZQ3: 43.6067546, -79.64894838560983
# 🔍 Missing coordinates for PWLO19R3. Attempting geocode...
# ✅ Geocoded PWLO19R3: 43.605456849999996, -79.65300176125949
# 🔍 Missing coordinates for BBGFQX6L. Attempting geocode...
# ✅ Geocoded BBGFQX6L: 43.58448695, -79.6211363943631
# 🔍 Missing coordinates for DE8LEBDC. Attempting geocode...
# ✅ Geocoded DE8LEBDC: 43.610351949999995, -79.6018136205488
# 🔍 Missing coordinates for O0LGHWCY. Attempting geocode...
# ✅ Geocoded O0LGHWCY: 43.6270285, -79.6300009
# 🔍 Missing coordinates for Y399KTHS. Attempting geocode...
# ✅ Geocoded Y399KTHS: 43.597162999999995, -79.63854806252439
# 🔍 Missing coordinates for VQNWO3LO. Attempting geocode...
# ✅ Geocoded VQNWO3LO: 43.58540415, -79.64389344844595

# %%
# print(employees) as a dataframe
employees_df = pd.DataFrame(employees)
print(employees_df)
# Out:
#      sur_name phone_number have_car first_name                        role  \
# 0       López   4378577691       No       Juan           [Cleaner, Labour]
# 1       Munoz   4374229494      Yes     Manuel  [Painter, Cleaner, Labour]
# 2       Munoz   4374603523       No       José                   [Cleaner]
# 3       Gómez   4378954592      Yes       José  [Labour, Cleaner, Painter]
# 42          30 Eglinton Avenue West , Mississauga
# 43            4557 Hurontario Street, Mississauga
# 44          30 Eglinton Avenue West , Mississauga
# 45                    25 John Street, Mississauga
# 46                 1055 Bloor Street, Mississauga
# 47                  4635 Tomken Road, Mississauga
# 48            1 Robert Speck Parkway, Mississauga
# 49       350 Burnhamthorpe Road West, Mississauga
#
#                             certificates middle_name   latitude  longitude
# 0            [Working at Heights, WHMIS]      Felipe  43.592196 -79.651387
# 1   [4 Steps, WHMIS, Working at Heights]    Mauricio  43.592276 -79.635140
# 2                              [4 Steps]        Jose  43.605457 -79.653002
# 3   [4 Steps, WHMIS, Working at Heights]      Felipe  43.592196 -79.651387
# 4            [Working at Heights, WHMIS]    Hernando  43.623916 -79.672020
# 5   [Working at Heights, WHMIS, 4 Steps]     Estiven  43.627029 -79.630001
# 6          [Working at Heights, 4 Steps]      Andres  43.605457 -79.653002
# 7                              [4 Steps]        Jose  43.627029 -79.630001
# 8                       [WHMIS, 4 Steps]      Felipe  43.584487 -79.621136
# 9          [Working at Heights, 4 Steps]      Felipe  43.628444 -79.676125
# 10  [4 Steps, Working at Heights, WHMIS]     Estiven  43.623916 -79.672020
# 11                      [WHMIS, 4 Steps]      Felipe  43.585404 -79.643893
# 12         [4 Steps, Working at Heights]      Felipe  43.584487 -79.621136
# 13  [4 Steps, Working at Heights, WHMIS]    Hernando  43.584487 -79.621136
# 14                             [4 Steps]      Andres  43.596682 -79.642363
# 15  [4 Steps, Working at Heights, WHMIS]        Jose  43.596682 -79.642363
# 16                      [WHMIS, 4 Steps]    Hernando  43.585404 -79.643893
# 17  [Working at Heights, 4 Steps, WHMIS]     Estiven  43.585404 -79.643893
# 18         [Working at Heights, 4 Steps]    Mauricio  43.574848 -79.608178
# 19                             [4 Steps]    Mauricio  43.597163 -79.638548
# 20  [4 Steps, WHMIS, Working at Heights]      Felipe  43.592196 -79.651387
# 21                      [4 Steps, WHMIS]      Andres  43.610352 -79.601814
# 22                      [WHMIS, 4 Steps]      Andres  43.628444 -79.676125
# 23  [Working at Heights, WHMIS, 4 Steps]        Jose  43.606755 -79.648948
# 24  [4 Steps, WHMIS, Working at Heights]        Jose  43.606755 -79.648948
# 25  [4 Steps, Working at Heights, WHMIS]      Andres  43.585404 -79.643893
# 26                               [WHMIS]      Felipe  43.574848 -79.608178
# 27                               [WHMIS]        Jose  43.585404 -79.643893
# 28                      [WHMIS, 4 Steps]    Mauricio  43.597163 -79.638548
# 29  [WHMIS, 4 Steps, Working at Heights]      Felipe  43.597163 -79.638548
# 30  [4 Steps, WHMIS, Working at Heights]    Mauricio  43.574848 -79.608178
# 31  [Working at Heights, WHMIS, 4 Steps]      Miguel  43.593912 -79.643892
# 32                  [Working at Heights]     Estiven  43.574848 -79.608178
# 33                  [Working at Heights]      Felipe  43.574848 -79.608178
# 34  [WHMIS, Working at Heights, 4 Steps]      Felipe  43.628444 -79.676125
# 35         [Working at Heights, 4 Steps]        Jose  43.592196 -79.651387
# 36  [Working at Heights, 4 Steps, WHMIS]     Estiven  43.585404 -79.643893
# 37                               [WHMIS]    Mauricio  43.584487 -79.621136
# 38                               [WHMIS]     Estiven  43.593912 -79.643892
# 39  [WHMIS, 4 Steps, Working at Heights]     Estiven  43.626835 -79.677679
# 40  [WHMIS, Working at Heights, 4 Steps]      Felipe  43.626835 -79.677679
# 41                  [Working at Heights]    Hernando  43.610352 -79.601814
# 42  [WHMIS, Working at Heights, 4 Steps]     Estiven  43.605457 -79.653002
# 43                               [WHMIS]    Hernando  43.606755 -79.648948
# 44  [Working at Heights, 4 Steps, WHMIS]     Estiven  43.605457 -79.653002
# 45         [Working at Heights, 4 Steps]      Miguel  43.584487 -79.621136
# 46  [WHMIS, 4 Steps, Working at Heights]    Hernando  43.610352 -79.601814
# 47  [WHMIS, 4 Steps, Working at Heights]     Estiven  43.627029 -79.630001
# 48                  [Working at Heights]        Jose  43.597163 -79.638548
# 49                      [4 Steps, WHMIS]        Jose  43.585404 -79.643893

# %%
# Feature Engineering
def calculate_distance(employee_location, site_location):
    return geopy.distance.distance(employee_location, site_location).km

# %%
print(f"📋 Employees Retrieved: {len(employees)}")
print(f"🏗️ Job Sites Retrieved: {len(job_sites)}")

# Print first 5 employees and job sites
for emp in employees[:5]:
    print(f"👤 Employee: {emp.get('worker_id', 'No ID')} | Role: {emp.get('role', 'No Role')} | Location: {emp.get('latitude', 'No Lat')}, {emp.get('longitude', 'No Lon')}")

for site in job_sites[:5]:
    print(f"🏗️ Job Site: {site.get('site_id', 'No ID')} | Required Roles: {site.get('required_roles', 'No Roles')} | Location: {site.get('latitude', 'No Lat')}, {site.get('longitude', 'No Lon')}")
# Out:
# 📋 Employees Retrieved: 50
# 🏗️ Job Sites Retrieved: 4
# 👤 Employee: DVCQQLCL | Role: ['Cleaner', 'Labour'] | Location: 43.5921963, -79.65138688125015
# 👤 Employee: 2084COEC | Role: ['Painter', 'Cleaner', 'Labour'] | Location: 43.5922757, -79.63514028047207
# 👤 Employee: 16SAR8R9 | Role: ['Cleaner'] | Location: 43.605456849999996, -79.65300176125949
# 👤 Employee: HNMRH170 | Role: ['Labour', 'Cleaner', 'Painter'] | Location: 43.5921963, -79.65138688125015
# 👤 Employee: BQYL7RR5 | Role: ['Painter', 'Labour', 'Cleaner'] | Location: 43.623916449999996, -79.67202003231276
# 🏗️ Job Site: SITE5148 | Required Roles: {'Cleaner': {'work_schedule': ['7:00-15:30'], 'num_workers': 1}, 'Labour': {'work_schedule': ['7:00-15:30'], 'num_workers': 1}} | Location: 43.55198488743175, -79.66416755049764
# 🏗️ Job Site: SITE8123 | Required Roles: {'Labour': {'work_schedule': ['7:00-15:30'], 'num_workers': 3}} | Location: 43.822017483251166, -79.0495549953297
# 🏗️ Job Site: SITE8308 | Required Roles: {'Labour': {'work_schedule': ['7:00-15:30'], 'num_workers': 1}} | Location: 43.68696788040313, -79.48927478058675
# 🏗️ Job Site: SITE9012 | Required Roles: {'Cleaner': {'work_schedule': ['7:00-15:30'], 'num_workers': 1}, 'Labour': {'work_schedule': ['7:00-15:30'], 'num_workers': 2}} | Location: 43.760807, -79.3514279918744

# %%
# ✅ Initialize assigned employees set
assigned_employees = set()

for site in job_sites:
    required_roles = site.get('required_roles', {})  
    assigned_counts = {role: 0 for role in required_roles}

    for role, role_data in required_roles.items():  # Extract role name and details
        required_count = role_data.get('num_workers', 0)
        if required_count == 0:
            continue

        print(f"\n🔎 Processing site {site['site_id']} - Role: {role}, Needs: {required_count}")

        employee_scores = []
        for employee in employees:
            score = 0  

            # ✅ Ensure we check the role correctly (since employee roles are lists)
            if role in employee.get('role', []):
                score += 5  

            # ✅ Availability Check
            if any(shift in employee.get('availability', []) for shift in role_data.get('work_schedule', [])):
                score += 4  

            # ✅ Has Car Check
            if employee.get('have_car', 'No') == 'Yes':
                score += 3  

            # ✅ Distance Calculation
            distance = calculate_distance((employee['latitude'], employee['longitude']), (site['latitude'], site['longitude']))
            if distance <= 40:
                score += 2  

            employee_scores.append({
                'employee': employee,
                'score': score,
                'distance': distance
            })

        # ✅ Sort employees by best match (highest score first, then highest rating)
        sorted_employees = sorted(employee_scores, key=lambda x: (-x['score'], x['distance'], -x['employee'].get('rating', 0)))

        print(f"🎯 {len(sorted_employees)} Employees Available for {role} at Site {site['site_id']}")

        # ✅ First, assign employees within 40km
        assigned = 0
        for emp_data in sorted_employees:
            if assigned >= required_count:
                break

            employee = emp_data['employee']

            if employee['worker_id'] in assigned_employees:
                continue

            # ✅ Enforce 40km limit unless no other choice
            if emp_data['distance'] > 40 and assigned < required_count:
                continue  

            print(f"⬆ Attempting Assignment: {employee['worker_id']} → {site['site_id']} (Score: {emp_data['score']}, Distance: {emp_data['distance']} km)")

            try:
                db.collection('assignments').add({
                    'employee_id': employee['worker_id'],
                    'job_site_id': site['site_id'],
                    'role': role,
                    'distance': emp_data['distance'],  # ✅ Add Distance
                    'assigned_date': datetime.now()
                })
                print(f"✅ Assigned {employee['worker_id']} to {site['site_id']} for {role} with score {emp_data['score']} and distance {emp_data['distance']} km.")
                assigned_employees.add(employee['worker_id'])
                assigned_counts[role] += 1
                assigned += 1
            except Exception as e:
                print(f"❌ Firestore Write Failed: {e}")

        # ✅ If no one was assigned within 40km, assign best available
        if assigned < required_count:
            print(f"⚠️ No employees found within 40km for {role} at {site['site_id']}. Assigning best available...")

            for emp_data in sorted_employees:
                if assigned >= required_count:
                    break

                employee = emp_data['employee']
                if employee['worker_id'] in assigned_employees:
                    continue

                print(f"⬆ Assigning Fallback: {employee['worker_id']} → {site['site_id']} (Distance: {emp_data['distance']} km)")

                try:
                    db.collection('assignments').add({
                        'employee_id': employee['worker_id'],
                        'job_site_id': site['site_id'],
                        'role': role,
                        'distance': emp_data['distance'],  # ✅ Add Distance
                        'assigned_date': datetime.now()
                    })
                    print(f"✅ Assigned {employee['worker_id']} (Fallback) to {site['site_id']} for {role}. Distance: {emp_data['distance']} km.")
                    assigned_employees.add(employee['worker_id'])
                    assigned_counts[role] += 1
                    assigned += 1
                except Exception as e:
                    print(f"❌ Firestore Write Failed: {e}")
# Out:
# 🔎 Processing site SITE5148 - Role: Cleaner, Needs: 1
# 🎯 50 Employees Available for Cleaner at Site SITE5148
# ⬆ Attempting Assignment: J30DTGPH → SITE5148 (Score: 14, Distance: 8.78235734270652 km)
# ✅ Assigned J30DTGPH to SITE5148 for Cleaner with score 14 and distance 8.78235734270652 km.
#
# 🔎 Processing site SITE5148 - Role: Labour, Needs: 1
# 🎯 50 Employees Available for Labour at Site SITE5148
# ⬆ Attempting Assignment: FVVIJE3B → SITE5148 (Score: 14, Distance: 4.05819579137333 km)
# ✅ Assigned FVVIJE3B to SITE5148 for Labour with score 14 and distance 4.05819579137333 km.
#
# 🔎 Processing site SITE8123 - Role: Labour, Needs: 3
# 🎯 50 Employees Available for Labour at Site SITE8123
# ⚠️ No employees found within 40km for Labour at SITE8123. Assigning best available...
# ⬆ Assigning Fallback: U54CSNUX → SITE8123 (Distance: 52.744354760859906 km)
# ✅ Assigned U54CSNUX (Fallback) to SITE8123 for Labour. Distance: 52.744354760859906 km.
# ⬆ Assigning Fallback: ZQUO11WI → SITE8123 (Distance: 53.90167175104349 km)
# ✅ Assigned ZQUO11WI (Fallback) to SITE8123 for Labour. Distance: 53.90167175104349 km.
# ⬆ Assigning Fallback: 2CVIC7VQ → SITE8123 (Distance: 54.645295663042134 km)
# ✅ Assigned 2CVIC7VQ (Fallback) to SITE8123 for Labour. Distance: 54.645295663042134 km.
#
# 🔎 Processing site SITE8308 - Role: Labour, Needs: 1
# 🎯 50 Employees Available for Labour at Site SITE8308
# ⬆ Attempting Assignment: RXBD2LAO → SITE8308 (Score: 11, Distance: 15.584191552339107 km)
# ✅ Assigned RXBD2LAO to SITE8308 for Labour with score 11 and distance 15.584191552339107 km.
#
# 🔎 Processing site SITE9012 - Role: Cleaner, Needs: 1
# 🎯 50 Employees Available for Cleaner at Site SITE9012
# ⬆ Attempting Assignment: YTLHDOG6 → SITE9012 (Score: 11, Distance: 29.25198768644423 km)
# ✅ Assigned YTLHDOG6 to SITE9012 for Cleaner with score 11 and distance 29.25198768644423 km.
#
# 🔎 Processing site SITE9012 - Role: Labour, Needs: 2
# 🎯 50 Employees Available for Labour at Site SITE9012
# ⬆ Attempting Assignment: HV4N1YU3 → SITE9012 (Score: 11, Distance: 29.713793106769764 km)
# ✅ Assigned HV4N1YU3 to SITE9012 for Labour with score 11 and distance 29.713793106769764 km.
# ⬆ Attempting Assignment: LJGFMSYJ → SITE9012 (Score: 11, Distance: 30.221454395640727 km)
# ✅ Assigned LJGFMSYJ to SITE9012 for Labour with score 11 and distance 30.221454395640727 km.
