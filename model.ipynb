# %%
import firebase_admin
from firebase_admin import credentials, firestore
import geopy.distance
from sklearn.ensemble import RandomForestClassifier
import pickle
import pandas as pd
from datetime import datetime


from geopy.geocoders import Nominatim


# Initialize Firebase Admin SDK
cred = credentials.Certificate('serviceAccountKey.json')


def initialize_firebase():
    try:
        # Check if Firebase has already been initialized
        if not firebase_admin._apps:
            cred = credentials.Certificate('serviceAccountKey.json')
            firebase_admin.initialize_app(cred)
        else:
            print("Firebase already initialized.")
    except Exception as e:
        print(f"Error initializing Firebase: {e}")

# Initialize Firebase (only once)
initialize_firebase()

# Initialize Firestore client
db = firestore.client()


# Fetch employee data
employees_ref = db.collection('employees')
employees = employees_ref.stream()

# Fetch job site data
job_sites_ref = db.collection('job_sites')
job_sites = job_sites_ref.stream()

# Example: employee and job site data
employee_data = [doc.to_dict() for doc in employees]
job_site_data = [doc.to_dict() for doc in job_sites]
# Out:
# Firebase already initialized.

# %%
# Geocoding function

geolocator = Nominatim(user_agent="OptiShiftApp")

def geocode_address(address):
    geolocator = Nominatim(user_agent="OptiShiftApp")
    location = geolocator.geocode(address, timeout=10)  # Increased timeout to 10 seconds
    if location:
        return location.latitude, location.longitude
    else:
        return None, None  # Return None if the geocoding fails

# Update employee and job site data with latitude and longitude
for employee in employee_data:
    lat, lon = geocode_address(employee['home_address'])
    employee['latitude'] = lat
    employee['longitude'] = lon

for site in job_site_data:
    lat, lon = geocode_address(site['location'])
    site['latitude'] = lat
    site['longitude'] = lon

# %%
# Printing employee id, latitude and longitude

for employee in employee_data:
    print(f"Employee ID: {employee['worker_id']}, Latitude: {employee['latitude']}, Longitude: {employee['longitude']}")
    print(f"Employee ID: {employee['worker_id']}, Home Address: {employee['home_address']}")
    print("\n")
# Out:
# Employee ID: KOO0MP1I, Latitude: 43.72182305209789, Longitude: -79.30367397595893
# Employee ID: KOO0MP1I, Home Address: 1871 O'Connor Drive, Toronto
#
#
# Employee ID: ORRFXDUB, Latitude: 43.6067546, Longitude: -79.64894838560983
# Employee ID: ORRFXDUB, Home Address: 4557 Hurontario Street, Mississauga
#
#
# Employee ID: TGKJTPX9, Latitude: 43.6711575, Longitude: -79.2941531
# Employee ID: TGKJTPX9, Home Address: 2255B Queen Street East, Toronto
#
#
# Employee ID: VKBOB7Z4, Latitude: 43.6711575, Longitude: -79.2941531
# Employee ID: VKBOB7Z4, Home Address: 2255B Queen Street East, Toronto
#
#
# Employee ID: P37NH11K, Latitude: 43.58540415, Longitude: -79.64389344844595
# Employee ID: P37NH11K, Home Address: 350 Burnhamthorpe Road West #401, Mississauga
#
#
# Employee ID: PKM5M17G, Latitude: None, Longitude: None
# Employee ID: PKM5M17G, Home Address: 50 Ashtonbee Road Unit 2, Scarborough
#
#
# Employee ID: L770NM18, Latitude: 43.71732965179992, Longitude: -79.31328883775146
# Employee ID: L770NM18, Home Address: 111 Bermondsey Road, North York
#
#
# Employee ID: YB4KNG8A, Latitude: 43.6711575, Longitude: -79.2941531
# Employee ID: YB4KNG8A, Home Address: 2255B Queen Street East, Toronto
#
#
# Employee ID: GAJHA3MR, Latitude: 43.610351949999995, Longitude: -79.6018136205488
# Employee ID: GAJHA3MR, Home Address: 1055 Bloor Street, Mississauga
#
#
# Employee ID: EMP4254, Latitude: 43.58655036666667, Longitude: -79.55024759999999
# Employee ID: EMP4254, Home Address: 1033 Deta Rd, Mississauga, ON
#
#
# Employee ID: BMPBM11R, Latitude: 43.6804838, Longitude: -79.3378399
# Employee ID: BMPBM11R, Home Address: 972 Danforth Avenue, Toronto
#
#
# Employee ID: CW8KXNVQ, Latitude: 43.59668175, Longitude: -79.64236258952329
# Employee ID: CW8KXNVQ, Home Address: 35 Square One Drive, Mississauga
#
#
# Employee ID: PXI9GCN6, Latitude: 43.5922757, Longitude: -79.63514028047207
# Employee ID: PXI9GCN6, Home Address: 3670 Hurontario Street, Mississauga
#
#
# Employee ID: BU1Z7IXP, Latitude: 43.6804838, Longitude: -79.3378399
# Employee ID: BU1Z7IXP, Home Address: 972 Danforth Avenue, Toronto
#
#
# Employee ID: H3XBY62O, Latitude: 43.6270285, Longitude: -79.6300009
# Employee ID: H3XBY62O, Home Address: 4635 Tomken Road, Mississauga
#
#
# Employee ID: H2WRP5MI, Latitude: 43.58448695, Longitude: -79.6211363943631
# Employee ID: H2WRP5MI, Home Address: 25 John Street, Mississauga
#
#
# Employee ID: FMDH76BU, Latitude: 43.574848, Longitude: -79.6081777
# Employee ID: FMDH76BU, Home Address: 2325 Hurontario Street, Mississauga
#
#
# Employee ID: HFUJBHS3, Latitude: 43.597162999999995, Longitude: -79.63854806252439
# Employee ID: HFUJBHS3, Home Address: 1 Robert Speck Parkway, Mississauga
#
#
# Employee ID: 6995W2XK, Latitude: None, Longitude: None
# Employee ID: 6995W2XK, Home Address: 3276 Saint Clair Avenue East, Scarborough
#
#
# Employee ID: BC03FHD9, Latitude: 43.726518146875, Longitude: -79.287282940625
# Employee ID: BC03FHD9, Home Address: 830 Warden Avenue, Scarborough
#
#
# Employee ID: IQK65FC2, Latitude: 43.6874638, Longitude: -79.28453404000001
# Employee ID: IQK65FC2, Home Address: 2488 Gerrard Street East, Scarborough
#
#
# Employee ID: QW0HWOIA, Latitude: 43.574848, Longitude: -79.6081777
# Employee ID: QW0HWOIA, Home Address: 2325 Hurontario Street, Mississauga
#
#
# Employee ID: 87U69IQ6, Latitude: 43.6881616, Longitude: -79.2983264
# Employee ID: 87U69IQ6, Home Address: 2681 Danforth Avenue, Toronto
#
#
# Employee ID: 55QEN9JE, Latitude: 43.6874638, Longitude: -79.28453404000001
# Employee ID: 55QEN9JE, Home Address: 2488 Gerrard Street East, Scarborough
#
#
# Employee ID: BZXJ0QL1, Latitude: 43.58448695, Longitude: -79.6211363943631
# Employee ID: BZXJ0QL1, Home Address: 25 John Street, Mississauga
#
#
# Employee ID: 56MIECOR, Latitude: 43.610351949999995, Longitude: -79.6018136205488
# Employee ID: 56MIECOR, Home Address: 1055 Bloor Street, Mississauga
#
#
# Employee ID: KLIPAJZZ, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: KLIPAJZZ, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: XPW2466O, Latitude: 43.5921963, Longitude: -79.65138688125015
# Employee ID: XPW2466O, Home Address: 309 Rathburn Road West, Mississauga
#
#
# Employee ID: I9QH498O, Latitude: 43.5921963, Longitude: -79.65138688125015
# Employee ID: I9QH498O, Home Address: 309 Rathburn Road West, Mississauga
#
#
# Employee ID: MUI9BBCW, Latitude: 43.58540415, Longitude: -79.64389344844595
# Employee ID: MUI9BBCW, Home Address: 350 Burnhamthorpe Road West #401, Mississauga
#
#
# Employee ID: 93IEIJC9, Latitude: 43.71732965179992, Longitude: -79.31328883775146
# Employee ID: 93IEIJC9, Home Address: 111 Bermondsey Road, North York
#
#
# Employee ID: DE86LQ7Q, Latitude: None, Longitude: None
# Employee ID: DE86LQ7Q, Home Address: 50 Ashtonbee Road Unit 2, Scarborough
#
#
# Employee ID: FIO339JH, Latitude: 43.62683465, Longitude: -79.67767878176727
# Employee ID: FIO339JH, Home Address: 50 Britannia Road East, Mississauga
#
#
# Employee ID: FJYWYRSQ, Latitude: 43.623916449999996, Longitude: -79.67202003231276
# Employee ID: FJYWYRSQ, Home Address: 100 Traders Boulevard East, Mississauga
#
#
# Employee ID: FTO9FBP9, Latitude: 43.58683765, Longitude: -79.64430920368173
# Employee ID: FTO9FBP9, Home Address: 325 Burnhamthorpe Road West, Mississauga
#
#
# Employee ID: 6L932C5B, Latitude: 43.58683765, Longitude: -79.64430920368173
# Employee ID: 6L932C5B, Home Address: 325 Burnhamthorpe Road West, Mississauga
#
#
# Employee ID: 0RS6I4A2, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: 0RS6I4A2, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: 7X8XJOW7, Latitude: 43.610351949999995, Longitude: -79.6018136205488
# Employee ID: 7X8XJOW7, Home Address: 1055 Bloor Street, Mississauga
#
#
# Employee ID: MDBH0FAI, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: MDBH0FAI, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: G5DWV6M3, Latitude: 43.726518146875, Longitude: -79.287282940625
# Employee ID: G5DWV6M3, Home Address: 830 Warden Avenue, Scarborough
#
#
# Employee ID: DMTPZ9NP, Latitude: 43.62683465, Longitude: -79.67767878176727
# Employee ID: DMTPZ9NP, Home Address: 50 Britannia Road East, Mississauga
#
#
# Employee ID: 5CR6MTZD, Latitude: 43.726518146875, Longitude: -79.287282940625
# Employee ID: 5CR6MTZD, Home Address: 830 Warden Avenue, Scarborough
#
#
# Employee ID: GUAG2C6K, Latitude: 43.58540415, Longitude: -79.64389344844595
# Employee ID: GUAG2C6K, Home Address: 350 Burnhamthorpe Road West #401, Mississauga
#
#
# Employee ID: 3D4EHDAJ, Latitude: None, Longitude: None
# Employee ID: 3D4EHDAJ, Home Address: 30 Eglinton Avenue West Ste 14, Mississauga
#
#
# Employee ID: IFAFF7F1, Latitude: None, Longitude: None
# Employee ID: IFAFF7F1, Home Address: 50 Ashtonbee Road Unit 2, Scarborough
#
#
# Employee ID: QZ2Z2UT8, Latitude: 43.5921963, Longitude: -79.65138688125015
# Employee ID: QZ2Z2UT8, Home Address: 309 Rathburn Road West, Mississauga
#
#
# Employee ID: XKOAD6ZV, Latitude: 43.597162999999995, Longitude: -79.63854806252439
# Employee ID: XKOAD6ZV, Home Address: 1 Robert Speck Parkway, Mississauga
#
#
# Employee ID: 7S06V0DD, Latitude: 43.5922757, Longitude: -79.63514028047207
# Employee ID: 7S06V0DD, Home Address: 3670 Hurontario Street, Mississauga
#
#
# Employee ID: JXFHK8HU, Latitude: 43.597162999999995, Longitude: -79.63854806252439
# Employee ID: JXFHK8HU, Home Address: 1 Robert Speck Parkway, Mississauga
#
#
# Employee ID: 48R75NGP, Latitude: 43.5922757, Longitude: -79.63514028047207
# Employee ID: 48R75NGP, Home Address: 3670 Hurontario Street, Mississauga
#
#
# Employee ID: 8TAPBMZP, Latitude: None, Longitude: None
# Employee ID: 8TAPBMZP, Home Address: 30 Eglinton Avenue West Ste 14, Mississauga
#
#
# Employee ID: 1OJ1GHG6, Latitude: 43.628444200000004, Longitude: -79.67612546062253
# Employee ID: 1OJ1GHG6, Home Address: 100 Britannia Road East, Mississauga
#
#
# Employee ID: WIA60XVB, Latitude: 43.72182305209789, Longitude: -79.30367397595893
# Employee ID: WIA60XVB, Home Address: 1871 O'Connor Drive, Toronto
#
#
# Employee ID: JG84PCN2, Latitude: 43.707519500000004, Longitude: -79.3143526418119
# Employee ID: JG84PCN2, Home Address: 7 Curity Avenue, Toronto
#
#
# Employee ID: GJI85UD8, Latitude: None, Longitude: None
# Employee ID: GJI85UD8, Home Address: 50 Ashtonbee Road Unit 2, Scarborough
#
#
# Employee ID: Y1A5E4QO, Latitude: 43.6874638, Longitude: -79.28453404000001
# Employee ID: Y1A5E4QO, Home Address: 2488 Gerrard Street East, Scarborough
#
#
# Employee ID: RBGOA167, Latitude: 43.6270285, Longitude: -79.6300009
# Employee ID: RBGOA167, Home Address: 4635 Tomken Road, Mississauga
#
#
# Employee ID: JRQU2Y58, Latitude: 43.6874638, Longitude: -79.28453404000001
# Employee ID: JRQU2Y58, Home Address: 2488 Gerrard Street East, Scarborough
#
#
# Employee ID: DJG0N4PT, Latitude: 43.707519500000004, Longitude: -79.3143526418119
# Employee ID: DJG0N4PT, Home Address: 7 Curity Avenue, Toronto
#
#
# Employee ID: 7ZC4R4BS, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: 7ZC4R4BS, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: 58Y38UMU, Latitude: 43.72496099999999, Longitude: -79.32745775693994
# Employee ID: 58Y38UMU, Home Address: 175 Wynford Drive, North York
#
#
# Employee ID: QL8G8Z8H, Latitude: 43.72496099999999, Longitude: -79.32745775693994
# Employee ID: QL8G8Z8H, Home Address: 175 Wynford Drive, North York
#
#
# Employee ID: 9GWAFPK5, Latitude: 43.6874638, Longitude: -79.28453404000001
# Employee ID: 9GWAFPK5, Home Address: 2488 Gerrard Street East, Scarborough
#
#
# Employee ID: AQ2HLOTW, Latitude: None, Longitude: None
# Employee ID: AQ2HLOTW, Home Address: 30 Eglinton Avenue West Ste 14, Mississauga
#
#
# Employee ID: 9KXLEGO6, Latitude: 43.58448695, Longitude: -79.6211363943631
# Employee ID: 9KXLEGO6, Home Address: 25 John Street, Mississauga
#
#
# Employee ID: D40SS5EM, Latitude: 43.6067546, Longitude: -79.64894838560983
# Employee ID: D40SS5EM, Home Address: 4557 Hurontario Street, Mississauga
#
#
# Employee ID: P5UBKONJ, Latitude: None, Longitude: None
# Employee ID: P5UBKONJ, Home Address: 11 Curity Avenue Unit 3, Toronto
#
#
# Employee ID: 020RPSYP, Latitude: 43.7261668, Longitude: -79.3022493
# Employee ID: 020RPSYP, Home Address: 1525 Victoria Park Avenue, Toronto
#
#
# Employee ID: ADGCJU7Z, Latitude: 43.628444200000004, Longitude: -79.67612546062253
# Employee ID: ADGCJU7Z, Home Address: 100 Britannia Road East, Mississauga
#
#
# Employee ID: 3CBLL2BD, Latitude: 43.610351949999995, Longitude: -79.6018136205488
# Employee ID: 3CBLL2BD, Home Address: 1055 Bloor Street, Mississauga
#
#
# Employee ID: 199YS5Q7, Latitude: 43.597162999999995, Longitude: -79.63854806252439
# Employee ID: 199YS5Q7, Home Address: 1 Robert Speck Parkway, Mississauga
#
#
# Employee ID: 0P1K8W41, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: 0P1K8W41, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: BXSTTCBZ, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: BXSTTCBZ, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: PW81RWPC, Latitude: 43.7261668, Longitude: -79.3022493
# Employee ID: PW81RWPC, Home Address: 1525 Victoria Park Avenue, Toronto
#
#
# Employee ID: 9DQ0QQ1V, Latitude: 43.72182305209789, Longitude: -79.30367397595893
# Employee ID: 9DQ0QQ1V, Home Address: 1871 O'Connor Drive, Toronto
#
#
# Employee ID: M4AJ3Y6L, Latitude: 43.610351949999995, Longitude: -79.6018136205488
# Employee ID: M4AJ3Y6L, Home Address: 1055 Bloor Street, Mississauga
#
#
# Employee ID: 8XEF1SND, Latitude: 43.71732965179992, Longitude: -79.31328883775146
# Employee ID: 8XEF1SND, Home Address: 111 Bermondsey Road, North York
#
#
# Employee ID: YMPMYVFX, Latitude: 43.6870145, Longitude: -79.3075565
# Employee ID: YMPMYVFX, Home Address: 2300 Danforth Avenue, Toronto
#
#
# Employee ID: WNEOF7TH, Latitude: 43.58540415, Longitude: -79.64389344844595
# Employee ID: WNEOF7TH, Home Address: 350 Burnhamthorpe Road West, Mississauga
#
#
# Employee ID: 3Q3BFVK3, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: 3Q3BFVK3, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: 7ONMC9YW, Latitude: 43.6067546, Longitude: -79.64894838560983
# Employee ID: 7ONMC9YW, Home Address: 4557 Hurontario Street, Mississauga
#
#
# Employee ID: SU7KA0QX, Latitude: 43.623916449999996, Longitude: -79.67202003231276
# Employee ID: SU7KA0QX, Home Address: 100 Traders Boulevard East, Mississauga
#
#
# Employee ID: V8RQICEH, Latitude: 43.6874638, Longitude: -79.28453404000001
# Employee ID: V8RQICEH, Home Address: 2488 Gerrard Street East, Scarborough
#
#
# Employee ID: 28LZRNBY, Latitude: 43.574848, Longitude: -79.6081777
# Employee ID: 28LZRNBY, Home Address: 2325 Hurontario Street, Mississauga
#
#
# Employee ID: 31P0L68L, Latitude: 43.58540415, Longitude: -79.64389344844595
# Employee ID: 31P0L68L, Home Address: 350 Burnhamthorpe Road West #401, Mississauga
#
#
# Employee ID: WL8YIEKY, Latitude: 43.72182305209789, Longitude: -79.30367397595893
# Employee ID: WL8YIEKY, Home Address: 1871 O'Connor Drive, Toronto
#
#
# Employee ID: GV969ZD2, Latitude: 43.574848, Longitude: -79.6081777
# Employee ID: GV969ZD2, Home Address: 2325 Hurontario Street, Mississauga
#
#
# Employee ID: EJF830WX, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: EJF830WX, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: 7RSX2ZUU, Latitude: 43.5939118, Longitude: -79.64389219049735
# Employee ID: 7RSX2ZUU, Home Address: 100 City Centre Drive, Mississauga
#
#
# Employee ID: TORN5GUE, Latitude: 43.7261668, Longitude: -79.3022493
# Employee ID: TORN5GUE, Home Address: 1525 Victoria Park Avenue, Toronto
#
#
# Employee ID: XFP4NFM7, Latitude: 43.597162999999995, Longitude: -79.63854806252439
# Employee ID: XFP4NFM7, Home Address: 1 Robert Speck Parkway, Mississauga
#
#
# Employee ID: PHJUJULZ, Latitude: None, Longitude: None
# Employee ID: PHJUJULZ, Home Address: 3276 Saint Clair Avenue East, Scarborough
#
#
# Employee ID: LVS3O5ZF, Latitude: None, Longitude: None
# Employee ID: LVS3O5ZF, Home Address: 30 Eglinton Avenue West Ste 14, Mississauga

# %%
employees_ref = db.collection('employees')

# Find employees with missing lat/long
for doc in employees_ref.stream():
    employee_data = doc.to_dict()
    if employee_data.get('latitude') is None or employee_data.get('longitude') is None:
        print(f"Employee ID: {doc.id}, Address: {employee_data.get('address', 'No Address')}")
# Out:
# Employee ID: 1XHNzFQqkq0HIOmK1Wxg, Address: No Address
# Employee ID: 1zbcW2qqPhixLNw4QhV0, Address: No Address
# Employee ID: 35Ppe5PLEGFKKFzglydS, Address: No Address
# Employee ID: 3AzQxQsDL28kRyTTdOEv, Address: No Address
# Employee ID: 3nSjIJA9M8Dw8wK4vfCQ, Address: No Address
# Employee ID: 4DCFeOP9g8pjNtEUH7Xc, Address: No Address
# Employee ID: 4MXpQopC65CsJxTZEHtx, Address: No Address
# Employee ID: 4X0jYChEDwy0D4BpAMwM, Address: No Address
# Employee ID: 5IqJuKgoQ502cXsccIeI, Address: No Address
# Employee ID: 5bMX9QqDTCMICwb9ywpl, Address: No Address
# Employee ID: 6aFsfBdX1PzRwi8g1qOr, Address: No Address
# Employee ID: 8BUCkq2YAusWO7n19j39, Address: No Address
# Employee ID: A3tu3n7THXD3x47B2hOx, Address: No Address
# Employee ID: AtPA2hAp2GiWqkJeGkWS, Address: No Address
# Employee ID: BE21B9HC53PaKWKIPHAE, Address: No Address
# Employee ID: BN83TL892zh417viQA2Q, Address: No Address
# Employee ID: DghW5uwy12reznHfiLLa, Address: No Address
# Employee ID: DqsFfZMQ0Azg9BKuDqYH, Address: No Address
# Employee ID: Du3ZJath17Lubh9CWGXt, Address: No Address
# Employee ID: EO8OEUGo7hym8KTj5oNF, Address: No Address
# Employee ID: F6jG2ZT5iJdtdy8MPsE8, Address: No Address
# Employee ID: FPcGTW0gaElATmIqgInJ, Address: No Address
# Employee ID: G9rinE1gozeerZNU2xdS, Address: No Address
# Employee ID: Gq4FkNr6MCnMSkKBwqEF, Address: No Address
# Employee ID: HGISNpll9gLd3YDJTk13, Address: No Address
# Employee ID: HOZED2c9oJlG04gE14lj, Address: No Address
# Employee ID: IInTIxkOTZ1NIL2RXkul, Address: No Address
# Employee ID: IQkEYBXcKfmxFx3VVmTY, Address: No Address
# Employee ID: JLm0q3oPKgPexS5vnsT1, Address: No Address
# Employee ID: JS7WtSvx3HvDqMVzioK0, Address: No Address
# Employee ID: JyYo6J9nNrb1BLTNs7a0, Address: No Address
# Employee ID: Kqjry63S15cnAhxGm0Mh, Address: No Address
# Employee ID: L7tDKoAR4gV1FkcENSvf, Address: No Address
# Employee ID: MYBSkVpfiVnKbE8uTaws, Address: No Address
# Employee ID: MpfgQDQ73B6u0LCk3YA7, Address: No Address
# Employee ID: Nb8t8MftrBSr5yovHSSy, Address: No Address
# Employee ID: O61Jc6iIVB3WZSQ6ce0Q, Address: No Address
# Employee ID: OAoUuhGmFTi110PIXlXH, Address: No Address
# Employee ID: OaZy2znb3c3i5DugRsVs, Address: No Address
# Employee ID: OkOACbdKR00tAMgu6ERC, Address: No Address
# Employee ID: OnKyCKdRL6vS6IGFUTst, Address: No Address
# Employee ID: RokBFsGRXiOQaIv040oa, Address: No Address
# Employee ID: RwMsfl2Gyn9EOpzYjW4N, Address: No Address
# Employee ID: ShMzYW4lL2ATGZySNVn4, Address: No Address
# Employee ID: UjlyeQG2nPbh3cI04xY0, Address: No Address
# Employee ID: VVO54Drl1ZeEYGY67GRb, Address: No Address
# Employee ID: VZB8VRHCO7iMPx2fbyOE, Address: No Address
# Employee ID: XlzNSC8IfmdWOAKqru2y, Address: No Address
# Employee ID: Yr9mR4u3aeUfaf662rkt, Address: No Address
# Employee ID: Z0yhYLfPKJFBeyNhIoCg, Address: No Address
# Employee ID: ZTlxmr7t93ECYi6yEAnM, Address: No Address
# Employee ID: Zgu1VcB9z0n1MyQtYolj, Address: No Address
# Employee ID: a45vGQVxJlk9WjW3YJlI, Address: No Address
# Employee ID: a4NQFFFRIcxBEnfPeaBg, Address: No Address
# Employee ID: as2fzbWDZIXiw0ziu9AR, Address: No Address
# Employee ID: bLd2Hrje4WhMNr7i200e, Address: No Address
# Employee ID: boLvf8KI5qfqzRQpgI2u, Address: No Address
# Employee ID: bqnI2keEWkfIo3whU6ZO, Address: No Address
# Employee ID: cgzjNAKSiIOtwQ5P9TuK, Address: No Address
# Employee ID: d4yPBue1vdCiCcUD7Rs9, Address: No Address
# Employee ID: dQdgJQZVMt50o3wFxqC2, Address: No Address
# Employee ID: e4KJ2qJcfZpWlvCAhCGL, Address: No Address
# Employee ID: eGYgbXIqGMz3LlREiYER, Address: No Address
# Employee ID: eQ9vtvzSJKPNS10Mk2hY, Address: No Address
# Employee ID: fsKQN4iRZh2NZNWBqarl, Address: No Address
# Employee ID: gRPKyFptE8ZdIEJRAfO2, Address: No Address
# Employee ID: htj2kCt10W0cae8Klp8J, Address: No Address
# Employee ID: iBKOwatqQDXOtPiDNHao, Address: No Address
# Employee ID: iPkYy32t0Aq1jzhx8RHq, Address: No Address
# Employee ID: iu8peCI1BNkrVw61qTQy, Address: No Address
# Employee ID: jQEpPNs0Ta1FT8YJ0ha9, Address: No Address
# Employee ID: jan21sRCaxzg89aAzLIB, Address: No Address
# Employee ID: jvyWMr8KG2XQqBrwTsVq, Address: No Address
# Employee ID: l92zmHuTFmsiFmCs1xXX, Address: No Address
# Employee ID: lFWgIfmP12F32byXXq8l, Address: No Address
# Employee ID: mUX30xG9KPwOOmztN15y, Address: No Address
# Employee ID: opXrxn0NpJdO9UUK5MNd, Address: No Address
# Employee ID: pAis2ryjL8lFIeVQsD8s, Address: No Address
# Employee ID: pHFkjZFDZD6dnswI8Ujx, Address: No Address
# Employee ID: q5XcRYMewFJueQLOHbfQ, Address: No Address
# Employee ID: rFX81ZBPWKof5iH7ysZt, Address: No Address
# Employee ID: sjLr4IBW1j5zhLXk4N7v, Address: No Address
# Employee ID: uIpbQPhnU8SwW1nyFJPw, Address: No Address
# Employee ID: uwAWepbN029CyVfRLLrX, Address: No Address
# Employee ID: v7vFdYRyLfmKYH9w3GYP, Address: No Address
# Employee ID: vBPYaTE3JrONVqznOxwY, Address: No Address
# Employee ID: vm2HobmPqAksFzMBQ7tK, Address: No Address
# Employee ID: wReBHMg8v5oiNznUF7vt, Address: No Address
# Employee ID: xBe1SgeS44cJKP2wUx06, Address: No Address
# Employee ID: xFeOtJtDS5w4LErAdFRH, Address: No Address
# Employee ID: y8EkC5P2dLguaWJmPWqE, Address: No Address
# Employee ID: ybN7ZO3TkBKNVRxAFFZ4, Address: No Address
# Employee ID: zdAIGtvSQbjgGjGRgJmL, Address: No Address

# %%
# Feature Engineering
def calculate_distance(employee_location, site_location):
    """Calculate distance between two locations."""
    return geopy.distance.distance(employee_location, site_location).km

# Create feature vectors
features = []
for employee in employee_data:
    for site in job_site_data:
        if employee['latitude'] is not None and site['latitude'] is not None:
            # Calculate distance between employee and job site
            employee_location = (employee['latitude'], employee['longitude'])
            site_location = (site['latitude'], site['longitude'])
            distance = calculate_distance(employee_location, site_location)
            
            feature_vector = {
                'employee_id': employee['worker_id'],
                'job_site_id': site['site_id'],
                'distance': distance,
                'available': employee['availability'],  # Other relevant features
                'role': employee['role']
            }
            features.append(feature_vector)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 10
#       8 for employee in employee_data:
#       9     for site in job_site_data:
# ---> 10         if employee['latitude'] is not None and site['latitude'] is not None:
#      11             # Calculate distance between employee and job site
#      12             employee_location = (employee['latitude'], employee['longitude'])
#      13             site_location = (site['latitude'], site['longitude'])
#
# TypeError: string indices must be integers, not 'str'

# %%
#print features as a dataframe
df = pd.DataFrame(features)
print(df.head(20))
# Out:
#    employee_id job_site_id   distance     available  role
# 0     KOO0MP1I    SITE1256   9.721641  [7:00-15:30]     0
# 1     KOO0MP1I    SITE1877  41.793459  [7:00-15:30]     0
# 2     KOO0MP1I    SITE1033  11.603362  [7:00-15:30]     0
# 3     KOO0MP1I    SITE6928  42.226789  [7:00-15:30]     0
# 4     KOO0MP1I    SITE9352  25.106379  [7:00-15:30]     0
# 5     KOO0MP1I    SITE6630  62.644572  [7:00-15:30]     0
# 6     KOO0MP1I    SITE3726  62.644572  [7:00-15:30]     0
# 7     KOO0MP1I    SITE6008  69.185013  [7:00-15:30]     0
# 8     KOO0MP1I    SITE8056  12.535557  [7:00-15:30]     0
# 9     KOO0MP1I    SITE3818  69.329909  [7:00-15:30]     0
# 10    KOO0MP1I    SITE5812   9.494257  [7:00-15:30]     0
# 11    KOO0MP1I    SITE5403   9.343881  [7:00-15:30]     0
# 12    KOO0MP1I    SITE1029  12.317600  [7:00-15:30]     0
# 13    KOO0MP1I    SITE2388  62.644572  [7:00-15:30]     0
# 14    KOO0MP1I    SITE7220   3.063226  [7:00-15:30]     0
# 15    KOO0MP1I    SITE7982  25.106379  [7:00-15:30]     0
# 16    KOO0MP1I    SITE2958  25.164841  [7:00-15:30]     0
# 17    KOO0MP1I    SITE1332  25.164841  [7:00-15:30]     0
# 18    KOO0MP1I    SITE9160  10.756572  [7:00-15:30]     0
# 19    ORRFXDUB    SITE1256  22.297177  [7:00-15:30]     0

# %%
from sklearn.preprocessing import LabelEncoder
import re

# Function to convert time range (e.g., '7:00-15:30' → 1 for available)
def convert_availability(time_range):
    # If time_range is a string and contains the range '7:00', it's available
    if isinstance(time_range, str) and '7:00' in time_range:  # Modify this logic as needed
        return 1  # Available
    return 0  # Unavailable

# Function to extract start time (e.g., '7:00-15:30' → 7)
def extract_start_time(time_range):
    if isinstance(time_range, str):
        match = re.match(r"(\d+):\d+-", time_range)
        if match:
            return int(match.group(1))
    return None

# Function to extract end time (e.g., '7:00-15:30' → 15)
def extract_end_time(time_range):
    if isinstance(time_range, str):
        match = re.match(r"- (\d+):\d+", time_range)
        if match:
            return int(match.group(1))
    return None

# Encode 'role' as a numeric feature
label_encoder = LabelEncoder()
for feature in features:
    feature['role'] = label_encoder.fit_transform([feature['role']])[0]  # Convert role to numeric

# Convert feature vectors to a DataFrame
df = pd.DataFrame(features)

# First, extract start and end times for time range strings in the 'available' column
df['start_time'] = df['available'].apply(extract_start_time)
df['end_time'] = df['available'].apply(extract_end_time)

# Now, apply the conversion function to the 'available' column (converts to binary)
df['available'] = df['available'].apply(convert_availability)

# Convert the columns to the correct types
df['distance'] = df['distance'].astype(float)  # Ensure 'distance' is a float
df['available'] = df['available'].astype(int)  # Ensure 'available' is an int

# Define the target variable (e.g., job_site_assignment: 1 for assigned, 0 for not assigned)
df['assigned'] = [1 if x['employee_id'] == x['job_site_id'] else 0 for x in features]

# Split data into features (X) and target (y)
X = df[['distance', 'available', 'role', 'start_time', 'end_time']]  # Add start_time and end_time as features if needed
y = df['assigned']


# prinf the data as a dataframe

print(X.head(20))
# Out:
#      distance  available  role start_time end_time
# 0    9.721641          0     0       None     None
# 1   41.793459          0     0       None     None
# 2   11.603362          0     0       None     None
# 3   42.226789          0     0       None     None
# 4   25.106379          0     0       None     None
# 5   62.644572          0     0       None     None
# 6   62.644572          0     0       None     None
# 7   69.185013          0     0       None     None
# 8   12.535557          0     0       None     None
# 9   69.329909          0     0       None     None
# 10   9.494257          0     0       None     None
# 11   9.343881          0     0       None     None
# 12  12.317600          0     0       None     None
# 13  62.644572          0     0       None     None
# 14   3.063226          0     0       None     None
# 15  25.106379          0     0       None     None
# 16  25.164841          0     0       None     None
# 17  25.164841          0     0       None     None
# 18  10.756572          0     0       None     None
# 19  22.297177          0     0       None     None

# %%
# Train the model
model = RandomForestClassifier()
model.fit(X, y)

# Save the model as a .pkl file
with open('job_assignment_model.pkl', 'wb') as f:
    pickle.dump(model, f)

print("Model trained and saved successfully.")
# Out:
# Model trained and saved successfully.

# %%
from sklearn.preprocessing import LabelEncoder
import pickle
import pandas as pd

# Load the trained model when needed
with open('job_assignment_model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Label encoder used during training
label_encoder = LabelEncoder()

# Simulate encoding for 'role' feature (use the same encoder you used in training)
role_data = ['Cleaner']  # Example role
role_encoded = label_encoder.fit_transform(role_data)  # Example: Encoding the role
role_encoded_value = role_encoded[0]  # Get the encoded value

# Prepare the new data for prediction, including all necessary features
new_data = pd.DataFrame({
    'distance': [10],
    'available': [1],  # Example feature
    'role': [role_encoded_value],  # Use the encoded role
    'start_time': [0],  # Assuming a default value (adjust as needed)
    'end_time': [0]    # Assuming a default value (adjust as needed)
})

# Use the model for predictions
prediction = loaded_model.predict(new_data)
print("Predicted assignment:", prediction)
# Out:
# Predicted assignment: [0]

# %%
from datetime import datetime
import pandas as pd

# Function to calculate distance between two geographical points
def calculate_distance(location1, location2):
    # Assuming this function is already defined, e.g., using the Haversine formula
    # location1 and location2 are tuples of (latitude, longitude)
    pass

# Daily predictions and updates
def assign_jobs_daily():
    # Fetch updated employee and job site data
    employees = employees_ref.stream()
    job_sites = job_sites_ref.stream()

    # Calculate new features
    features = []
    for employee in employees:
        employee_data = employee.to_dict()  # Convert DocumentSnapshot to dictionary
        for site in job_sites:
            site_data = site.to_dict()  # Convert DocumentSnapshot to dictionary
            
            # Safely get latitude and longitude using .get() to avoid KeyError
            employee_latitude = employee_data.get('latitude', None)
            employee_longitude = employee_data.get('longitude', None)
            site_latitude = site_data.get('latitude', None)
            site_longitude = site_data.get('longitude', None)
            
            # If any of the latitude/longitude values are missing, skip this feature
            if None in [employee_latitude, employee_longitude, site_latitude, site_longitude]:
                continue
            
            # Calculate distance and generate feature vector
            employee_location = (employee_latitude, employee_longitude)
            site_location = (site_latitude, site_longitude)
            distance = calculate_distance(employee_location, site_location)
            
            feature_vector = {
                'employee_id': employee_data['worker_id'],
                'job_site_id': site_data['site_id'],
                'distance': distance,
                'available': employee_data['availability'],
                'role': employee_data['role']
            }
            features.append(feature_vector)
    
    # Ensure features list is not empty
    if not features:
        print("No valid features generated. Exiting.")
        return

    # Predict using the saved model
    new_data = pd.DataFrame(features)
    predictions = loaded_model.predict(new_data)
    
    # Assign employees to job sites based on predictions
    for i, prediction in enumerate(predictions):
        if prediction == 1:
            employee_id = features[i]['employee_id']
            job_site_id = features[i]['job_site_id']
            # Update the assignment in Firestore
            db.collection('shift_assignments').add({
                'employee_id': employee_id,
                'job_site_id': job_site_id,
                'assigned_date': datetime.now()
            })

# Call daily assignment function
assign_jobs_daily()
# Out:
# No valid features generated. Exiting.
